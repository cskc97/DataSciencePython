# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from pandas import Series,DataFrame

# %%
# %matplotlib inline

# %%
rcParams["figure.figsize"]=5,4

# %%
#add_axes([xpos,ypos,width,height])
x=range(1,10)
y=[1,2,3,4,0,4,3,2,1]
figure = plt.figure()

axes = figure.add_axes([5,5,1,1])
# axes.set_xlim([1,5])
# axes.set_ylim([1,5])
# x_lim and y_lim sets limits to axes. 
axes.plot(x,y)

# %%
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <Container object of 9 artists>

# %%
x=range(1,10)
y=[1,2,3,4,0,4,3,2,1]
figure = plt.figure()

axes = figure.add_axes([0,0,1,1])
axes.grid()
axes.plot(x,y)

# %%
'''
Return a subplot axes positioned by the given grid definition.

Typical call signature:

subplot(nrows, ncols, plot_number)
Where nrows and ncols are used to notionally split the figure into nrows * ncols
sub-axes, and plot_number is used to identify the particular subplot that this
function is to create within the notional grid. 
plot_number starts at 1, increments across rows first and has a maximum of nrows
* ncols.

'''

x=range(1,10)
y=[1,2,3,4,0,4,3,2,1]

axes = figure.add_axes([0,0,1,1])
fig, (ax1,ax2) = plt.subplots(1,2)

ax1.plot(x)
ax2.plot(x,y)

# %%
#Multiple plits in one figure with subplots. 
figure_obj = plt.figure()
figure_obj, (axes_1,axes_2,axes_3) = plt.subplots(1,3) 
#In subplots():
#first value is the number of rows
#second value is the number of columns.

axes_1.plot(x)
axes_2.plot(x,y)
axes_3.plot(y)
