# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

import matplotlib.pyplot as plt

# %%
x = range(0,9)
print(x)

y = [1,2,3,4,3,5,4,3,2,]
plt.bar(x,y,color=["purple","red","green"])
plt.xlabel("X LABEL")
plt.ylabel("Y LABEL")
plt.show()
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
z = [1,2,3,4,5]
type = ["Cycle","Bike","Scooter","Van","Car"]
plt.pie(z,labels=type)

plt.show()

# %%
cars = pd.read_csv("mtcars.csv")
columns = cars.columns
cols = list(columns)
cols
cols[0] = "car_names"
print(cols)
# Out:
# ['car_names', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

# %%
cars.columns = cols
cars.head()
# Out:
#            car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mpg = cars["mpg"]
mpg
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names,rotation=60,fontsize="medium")
ax.set_title( "Miles per Gallon of Cars in mtcars")
ax.set_xlabel("Car Names")
ax.set_ylabel("miles/gallon")
ax.plot(mpg)
plt.show()

# %%
plt.pie(z)
plt.legend(type,loc="best")

plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names,rotation=60,fontsize="medium")
ax.set_title( "Miles per Gallon of Cars in mtcars")
ax.set_xlabel("Car Names")
ax.set_ylabel("miles/gallon")

ax.plot(mpg)
ax.annotate("Toyota Corolla",xy=(19,33.9),xytext=(21,34),arrowprops=dict(facecolor="black"))
#xy is the position in terms of the data. x=19 (19th item) and y=33.9 (y value itself)
#so xy is basically the xvalue and the yvalue. 
plt.show()
